# %% [markdown]
# # Google Colab
# Trying out some simple Maths functions.
#
# Imports out of the way first:

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import networkx as nx
import graphviz

# !pip install treelib
import treelib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: treelib in /usr/local/lib/python3.7/dist-packages (1.6.1)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from treelib) (0.16.0)

# %% [markdown]
# Now an example graph of $x^2$

# %%
x=np.linspace(-10,10,100)
plt.plot(x, x**2)
plt.title("Square ")
# Out:
# Text(0.5, 1.0, 'Square ')

# %% [markdown]
# Some examples from notes: square root inverse, $y=1/\sqrt(x+1)$
#
# Domain for this function is $(-1,\infty ] $
#
# To avoid overflow in drawing the graph, we specify `endpoint=False` and write the interval as `5, -1` so that the endpoint is applied to `-1`.

# %%
x=np.linspace(5,-1, endpoint=False)
y=1/(np.sqrt(x +1) )
plt.plot(x, y)
plt.title("Function example")
# Out:
# Text(0.5, 1.0, 'Function example')

# %% [markdown]
# Sketch a function

# %%
x=np.linspace(-2,3,6)
y=1+x**2
x1=np.linspace(-2,3)
y1=1+x1**2
plt.plot(x1,y1)
plt.plot(x,y,'o')
plt.title("Sketched Graph $y=1+x^2$")
# Out:
# Text(0.5, 1.0, 'Sketched Graph $y=1+x^2$')

# %% [markdown]
# # Now some graphs
# Sketch a directed graph:
#
# $ N=(1,2,3,4,5) $
#
# $ E=\{(1,2) ,(1,3),(3,3),(4,2),(5,4),(4,3)\} $

# %% [markdown]
# Set up node options first

# %%
options = {
    "font_size": 16,
    "node_size": 600,
    "node_color": "white",
    "edgecolors": "black",
    "linewidths": 2,
    "width": 2,

}

# %%
G=nx.DiGraph()
G.add_edges_from([(1,2),(1,3),(3,3),(4,2),(5,4),(4,3)])
nx.draw_planar (G, with_labels=True, **options)

# Set margins for the axes so that nodes aren't clipped
ax = plt.gca()
ax.margins(0.20)
plt.axis("off")
plt.show()

# From https://networkx.org/documentation/stable/auto_examples/basic/plot_simple_graph.html

# %% [markdown]
# # Trees
# Using plotly
# https://plotly.com/python/tree-plots/

# %%
 tree = Tree()

 tree.create_node("Harry", "harry")  # No parent means its the root node
 tree.create_node("Jane",  "jane"   , parent="harry")
 tree.create_node("Bill",  "bill"   , parent="harry")
 tree.create_node("Diane", "diane"  , parent="jane")
 tree.create_node("Mary",  "mary"   , parent="diane")
 tree.create_node("Mark",  "mark"   , parent="jane")

 gvt=tree.to_graphviz()
 grph = graphviz.Source(gvt)
 
 nxt=nx.nx_agraph.from_agraph(grph,nx.DiGraph)
 nxt.show()
# Out:
# digraph tree {
# 	"harry" [label="Harry", shape=circle]
# 	"bill" [label="Bill", shape=circle]
# 	"jane" [label="Jane", shape=circle]
# 	"diane" [label="Diane", shape=circle]
# 	"mark" [label="Mark", shape=circle]
# 	"mary" [label="Mary", shape=circle]
#
# 	"harry" -> "jane"
# 	"harry" -> "bill"
# 	"jane" -> "diane"
# 	"jane" -> "mark"
# 	"diane" -> "mary"
# }
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-5947c07a0459> in <module>()
#      11 grph = graphviz.Source(gvt)
#      12
# ---> 13 nxt=nx.nx_agraph.from_agraph(grph,nx.DiGraph)
#      14 nxt.show()
#
# /usr/local/lib/python3.7/dist-packages/networkx/drawing/nx_agraph.py in from_agraph(A, create_using)
#      78     # assign defaults
#      79     N = nx.empty_graph(0, create_using)
# ---> 80     if A.name is not None:
#      81         N.name = A.name
#      82
#
# AttributeError: 'Source' object has no attribute 'name'
